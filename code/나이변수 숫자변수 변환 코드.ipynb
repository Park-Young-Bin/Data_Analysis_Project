# %% [markdown]
# ## 나이변수 숫자변수 변환 코드

# %%
import pandas as pd

# %%
df = pd.read_csv('accidentInfoList.csv')
df.head(2)
# Out:
#                사고번호              사고일시   요일              시군구  사고내용  사망자수  중상자수  \
# 0  2015011700100130  2015년 1월 17일 06시  토요일   경기도 수원시 권선구 탑동  사망사고     1     0
# 1  2015012500100260  2015년 1월 25일 18시  일요일  경기도 수원시 장안구 영화동  사망사고     1     2
#
#    경상자수  부상신고자수        사고유형  ... 기상상태        도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 0     0       0  차대사람 - 횡단중  ...   맑음  교차로 - 교차로안       승용        남      62세
# 1     0       0  차대사람 - 횡단중  ...    비    단일로 - 기타       승용        남      40세
#
#   가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 0       상해없음      보행자        남      53세         사망
# 1       상해없음      보행자        남      59세         사망
#
# [2 rows x 22 columns]

# %%
df['피해운전자 연령'] = df['피해운전자 연령'].str.extract('(\d+)')

# %%
df
# Out:
#                 사고번호               사고일시   요일                시군구  사고내용  사망자수  \
# 0   2015011700100130   2015년 1월 17일 06시  토요일     경기도 수원시 권선구 탑동  사망사고     1
# 1   2015012500100260   2015년 1월 25일 18시  일요일    경기도 수원시 장안구 영화동  사망사고     1
# 2   2015012900100468   2015년 1월 29일 20시  목요일    경기도 수원시 영통구 영통동  사망사고     1
# 3   2015061000100040   2015년 6월 10일 03시  수요일    경기도 수원시 팔달구 화서동  사망사고     1
# 4   2015062700100104   2015년 6월 27일 04시  토요일    경기도 수원시 장안구 파장동  사망사고     1
# 5   2015070700100082    2015년 7월 7일 06시  화요일  경기도 수원시 팔달구 매산로1가  사망사고     1
# 6   2015080500100010    2015년 8월 5일 00시  수요일    경기도 수원시 권선구 구운동  사망사고     1
# 7   2015092700100059   2015년 9월 27일 05시  일요일  경기도 수원시 팔달구 매산로1가  사망사고     1
# 8   2015101400100062  2015년 10월 14일 05시  수요일    경기도 수원시 팔달구 인계동  사망사고     1
# 9   2015111300100073  2015년 11월 13일 05시  금요일  경기도 수원시 팔달구 매산로1가  사망사고     1
# 10  2015122200100225  2015년 12월 22일 11시  화요일  경기도 수원시 팔달구 매산로2가  사망사고     1
# ...

# %%
df = df[df['피해운전자 연령'] >= '65']

# %%
pd.to_numeric(df['aa'])

# %%
df
# Out:
#                 사고번호               사고일시   요일                시군구  사고내용  사망자수  \
